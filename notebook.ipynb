# %% [markdown]
# ## WebExtensions Disabled Intermittents Report
#
# This notebook queries bugzilla for the WebExtension intermittents that have been disabled (and merge the fresh data coming from bugzilla with the additional data loaded from csv file of notes, which contains the details of the platforms on which it has been disabled).

# %%
from helpers import report_webext_disabled_intermittents

# %% [markdown]
# **NOTE:** In the following table the intermittents disabled on Windows are marked as red (based on the column "Disabled on", which is coming from the csv file).
#
# The table is ordered based on **priority** (from *untriaged* and *P1*), **Core Platform** and **last change time**.

# %%
report_webext_disabled_intermittents()
# Out:
# 'Number of notes related to disabled intermittents loaded from csv: 16'
# 'Number of disabled intermittents found on bugzilla: 16'
# 'Last generated: 2018-03-12 15:45:37.891229'
# <style  type="text/css" >
# </style>
# <table id="T_074bd3c0_2604_11e8_b73b_f45c899b4cd1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >&#x1F517;</th>
#         <th class="col_heading level0 col1" >Test</th>
#         <th class="col_heading level0 col2" >status</th>
#         <th class="col_heading level0 col3" >priority</th>
#         <th class="col_heading level0 col4" >Disabled on</th>
#         <th class="col_heading level0 col5" >Core Platform</th>
#         <th class="col_heading level0 col6" >whiteboard</th>
#         <th class="col_heading level0 col7" >assigned_to</th>
#         <th class="col_heading level0 col8" >see_also</th>
#         <th class="col_heading level0 col9" >last_change_time</th>
#     </tr>    <tr>
# ...
